# %%
from tensorflow.python import pywrap_tensorflow
from tensorflow.python.tools.inspect_checkpoint import print_tensors_in_checkpoint_file
# Out:
# c:\users\smmeenehan\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pre_trained_ckpt = './faster_rcnn_resnet50_checkpoint/model.ckpt'
print_tensors_in_checkpoint_file(pre_trained_ckpt, '', all_tensors=False, all_tensor_names=True)
# Out:
# tensor_name:  Conv/biases
# tensor_name:  Conv/weights
# tensor_name:  FirstStageBoxPredictor/BoxEncodingPredictor/biases
# tensor_name:  FirstStageBoxPredictor/BoxEncodingPredictor/weights
# tensor_name:  FirstStageBoxPredictor/ClassPredictor/biases
# tensor_name:  FirstStageBoxPredictor/ClassPredictor/weights
# tensor_name:  FirstStageFeatureExtractor/resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/beta
# tensor_name:  FirstStageFeatureExtractor/resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/gamma
# tensor_name:  FirstStageFeatureExtractor/resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/moving_mean
# tensor_name:  FirstStageFeatureExtractor/resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/moving_variance
# tensor_name:  FirstStageFeatureExtractor/resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/weights
# tensor_name:  FirstStageFeatureExtractor/resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/beta
# ...
